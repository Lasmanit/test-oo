# %%
print('Hello Pyhton!')
# Out:
# Hello Pyhton!

# %%
import sys

# %%
import sys
print('sys version')
# Out:
# sys version

# %%
import sys
print(sys.version)
# Out:
# 3.8.12 (default, Oct 12 2021, 13:49:34)
# [GCC 7.5.0]

# %%
print('notie') #a comment for me
# Out:
# notie

# %%
type(3.44) #the command type will interpert what kind of number I wrote
# Out:
# float

# %%
type('hello darkness my old friend')
# Out:
# str

# %%
type(0)
# Out:
# int

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
float(5) #convert int to float
# Out:
# 5.0

# %%
int(5.5) #convert to int
# Out:
# 5

# %%
type(float(3))
# Out:
# float

# %%
int(1) #convert string to int
# Out:
# 1

# %%
str(9.012) #convert float to string. notice the ''
# Out:
# '9.012'

# %%
True #Boolean FOR True of Flase
# Out:
# True

# %%
type (False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
type(3) #type(6//2) # int, as the double slashes stand for integer division
# Out:
# int

# %%
type(3.0) #foat sinse one slash stand fot float division
# Out:
# float

# %%
100+30+12 #Expression xpressions in Python can include operations among compatible types (e.g., integers and floats). For example, basic arithmetic operations like adding multiple
# Out:
# 142

# %%
10-30
# Out:
# -20

# %%
5*5 #Multiplication operation expression
# Out:
# 25

# %%
25/5 #Division operation expression with forword slash!!!
# Out:
# 5.0

# %%
25/6
# Out:
# 4.166666666666667

# %%
25//6
# Out:
# 4

# %%
x=10-2*6 #store value in a variable

# %%
x #execute the value
# Out:
# -2

# %%
y=x+4 #I can define another variable with the first one that Ive defined

# %%
y
# Out:
# 2

# %%
x=60/2 #If we save a value to an existing variable, the new value will overwrite the previous value

# %%
x
# Out:
# 30.0

# %%
x=60//2

# %%
x
# Out:
# 30

# %%
rinat_age=5+16+12

# %%
Ilan_age=rinat_age+1

# %%
Ilan_age
# Out:
# 33
